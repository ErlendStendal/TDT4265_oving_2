# %%
import pathlib
import matplotlib.pyplot as plt
import utils
import torch
from torch import nn
from dataloaders import load_cifar10
from trainer import compute_loss_and_accuracy
from trainer import Trainer
from task3 import create_plots
from task3 import print_accuracy

# %%
class ExampleModel(nn.Module):
    def __init__(self, image_channels, num_classes):
        """
        Is called when model is initialized.
        Args:
            image_channels. Number of color channels in image (3)
            num_classes: Number of classes we want to predict (10)
        """
        super().__init__()
        # TODO: Implement this function (Task  2a)
        num_filters = 32  # Set number of filters in first conv layer
        self.num_classes = num_classes
        # Define the convolutional layers
        self.feature_extractor = nn.Sequential(
            nn.Conv2d(
                in_channels=image_channels,
                out_channels=num_filters,
                kernel_size=3,
                stride=1,
                padding=1,
            ),
            nn.MaxPool2d(2, 2),
            nn.BatchNorm2d(num_filters),
            #nn.Dropout(0.1),
            #nn.ReLU(),
            nn.LeakyReLU(0.02),
            nn.Conv2d(
                in_channels=32,
                out_channels=32,
                kernel_size=3,
                stride=1,
                padding=1,
            ),
            #nn.ReLU(),
            nn.LeakyReLU(0.02),
            nn.BatchNorm2d(32),
            
            nn.Conv2d(
                in_channels=32,
                out_channels=64,
                kernel_size=3,
                stride=1,
                padding=1,
            ),
            nn.MaxPool2d(2, 2),
            #nn.Dropout(0.05),
            #nn.ReLU(),
            nn.LeakyReLU(0.02),
            nn.BatchNorm2d(64),
            
            nn.Conv2d(
                in_channels=64,
                out_channels=64,
                kernel_size=3,
                stride=1,
                padding=1,
            ),
            #nn.ReLU(),
            nn.LeakyReLU(0.02),
            nn.BatchNorm2d(64),

            nn.Conv2d(
                in_channels=64,
                out_channels=64,
                kernel_size=3,
                stride=1,
                padding=1,
            ),
            #nn.ReLU(),
            nn.LeakyReLU(0.02),
            nn.BatchNorm2d(64),
       
            nn.Conv2d(
                in_channels=64,
                out_channels=128,
                kernel_size=3,
                stride=1,
                padding=1,
            ),
            nn.MaxPool2d(2, 2),
            nn.BatchNorm2d(128),
            #nn.ReLU(),
            nn.LeakyReLU(0.02),
            nn.Conv2d(
                in_channels=128,
                out_channels=128,
                kernel_size=3,
                stride=1,
                padding=1,
            ),
            #nn.MaxPool2d(2, 2),
            nn.BatchNorm2d(128),
            #nn.ReLU()
            nn.LeakyReLU(0.02)
        )

        # The output of feature_extractor will be [batch_size, num_filters, 16, 16]
        
        self.num_output_features = 128 * 4 * 4
        #self.num_output_features = 64 * 8 * 8
        # Initialize our last fully connected layer
        # Inputs all extracted features from the convolutional layers
        # Outputs num_classes predictions, 1 for each class.
        # There is no need for softmax activation function, as this is
        # included with nn.CrossEntropyLoss
        self.classifier = nn.Sequential(
            #nn.Linear(self.num_output_features, 64),
            #nn.BatchNorm1d(64),
            #nn.ReLU(),
            #nn.LeakyReLU(0.02),
            #nn.Linear(64 , num_classes)
            nn.Linear(self.num_output_features , num_classes)
        )

    def forward(self, x):
        """
        Performs a forward pass through the model
        Args:
            x: Input image, shape: [batch_size, 3, 32, 32]
        """
        # TODO: Implement this function (Task  2a)
        batch_size = x.shape[0]
        x = self.feature_extractor(x)
        x = x.view(-1, self.num_output_features) #flatten
        
        out = self.classifier(x)
        expected_shape = (batch_size, self.num_classes)
        assert out.shape == (
            batch_size,
            self.num_classes,
        ), f"Expected output of forward pass to be: {expected_shape}, but got: {out.shape}"
        return out

# %%
def create_plots_compare(trainer1: Trainer, trainer2: Trainer, name: str):
    plot_path = pathlib.Path("plots")
    plot_path.mkdir(exist_ok=True)
    # Save plots and show them
    plt.figure(figsize=(20, 8))
    plt.subplot(1, 2, 1)
    plt.title("Cross Entropy Loss")
    utils.plot_loss(
        trainer1.train_history["loss"], label="Training loss before", npoints_to_average=10
    )
    utils.plot_loss(
        trainer2.train_history["loss"], label="Training loss after", npoints_to_average=10
    )
    utils.plot_loss(trainer1.validation_history["loss"], label="Validation loss before")
    utils.plot_loss(trainer2.validation_history["loss"], label="Validation loss after")
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.title("Accuracy")
    utils.plot_loss(trainer1.validation_history["accuracy"], label="Validation Accuracy before")
    utils.plot_loss(trainer2.validation_history["accuracy"], label="Validation Accuracy after")
    plt.legend()
    plt.savefig(plot_path.joinpath(f"{name}_plot.png"))
    plt.show()

# %%
utils.set_seed(0)
print(f"Using device: {utils.get_device()}")
epochs = 10
batch_size = 64
learning_rate = 5.5e-1
early_stop_count = 8
dataloaders = load_cifar10(batch_size)
model = ExampleModel(image_channels=3, num_classes=10)
trainer = Trainer(
    batch_size, learning_rate, early_stop_count, epochs, model, dataloaders
)
trainer.optimizer = torch.optim.Adadelta(model.parameters(), learning_rate)

trainer.train()
print_accuracy(trainer)
create_plots(trainer, "task3")
# Out:
# Using device: cuda
# Files already downloaded and verified
# Files already downloaded and verified
# ExampleModel(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): LeakyReLU(negative_slope=0.02)
#     (4): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): LeakyReLU(negative_slope=0.02)
#     (6): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): LeakyReLU(negative_slope=0.02)
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): LeakyReLU(negative_slope=0.02)
#     (13): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): LeakyReLU(negative_slope=0.02)
#     (16): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (20): LeakyReLU(negative_slope=0.02)
#     (21): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (23): LeakyReLU(negative_slope=0.02)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=10, bias=True)
#   )
# )
# Epoch: 0, Batches per seconds: 292.65, Global step:    351, Validation Loss: 1.19, Validation Accuracy: 0.572
# Epoch: 0, Batches per seconds: 250.39, Global step:    702, Validation Loss: 0.97, Validation Accuracy: 0.660
# Epoch: 1, Batches per seconds: 236.42, Global step:   1053, Validation Loss: 0.95, Validation Accuracy: 0.666
# Epoch: 1, Batches per seconds: 237.28, Global step:   1404, Validation Loss: 0.77, Validation Accuracy: 0.733
# Epoch: 2, Batches per seconds: 237.49, Global step:   1755, Validation Loss: 0.71, Validation Accuracy: 0.754
# Epoch: 2, Batches per seconds: 231.99, Global step:   2106, Validation Loss: 0.73, Validation Accuracy: 0.746
# Epoch: 3, Batches per seconds: 233.77, Global step:   2457, Validation Loss: 0.69, Validation Accuracy: 0.769
# Epoch: 3, Batches per seconds: 234.20, Global step:   2808, Validation Loss: 0.63, Validation Accuracy: 0.783
# Epoch: 4, Batches per seconds: 234.14, Global step:   3159, Validation Loss: 0.73, Validation Accuracy: 0.759
# Epoch: 4, Batches per seconds: 232.94, Global step:   3510, Validation Loss: 0.64, Validation Accuracy: 0.794
# Epoch: 5, Batches per seconds: 234.47, Global step:   3861, Validation Loss: 0.63, Validation Accuracy: 0.800
# Epoch: 5, Batches per seconds: 236.37, Global step:   4212, Validation Loss: 0.66, Validation Accuracy: 0.792
# Epoch: 6, Batches per seconds: 236.65, Global step:   4563, Validation Loss: 0.66, Validation Accuracy: 0.797
# Epoch: 6, Batches per seconds: 239.50, Global step:   4914, Validation Loss: 0.62, Validation Accuracy: 0.808
# Epoch: 7, Batches per seconds: 239.44, Global step:   5265, Validation Loss: 0.70, Validation Accuracy: 0.795
# Epoch: 7, Batches per seconds: 239.51, Global step:   5616, Validation Loss: 0.70, Validation Accuracy: 0.795
# Epoch: 8, Batches per seconds: 239.42, Global step:   5967, Validation Loss: 0.71, Validation Accuracy: 0.800
# Epoch: 8, Batches per seconds: 238.46, Global step:   6318, Validation Loss: 0.71, Validation Accuracy: 0.804
# Epoch: 9, Batches per seconds: 239.37, Global step:   6669, Validation Loss: 0.73, Validation Accuracy: 0.808
# Epoch: 9, Batches per seconds: 238.47, Global step:   7020, Validation Loss: 0.75, Validation Accuracy: 0.808
# Dataset: train, Accuracy: 0.941, loss: 0.178
# Dataset: test, Accuracy: 0.805, loss: 0.647
# Dataset: val, Accuracy: 0.807, loss: 0.630

# %%
last_trainer = trainer

# %%
create_plots_compare(last_trainer, trainer, "comparison plot")
