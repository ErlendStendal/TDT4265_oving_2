# %% [markdown]
# # Assignment 1 Report

# %% [markdown]
# This is an outline for your report to ease the amount of work required to create your report. Jupyter notebook supports markdown, and I recommend you to check out this [cheat sheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet). If you are not familiar with markdown.
#
# Before delivery, **remember to convert this file to PDF**. You can do it in two ways:
# 1. Print the webpage (ctrl+P or cmd+P)
# 2. Export with latex. This is somewhat more difficult, but you'll get somehwat of a "prettier" PDF. Go to File -> Download as -> PDF via LaTeX. You might have to install nbconvert and pandoc through conda; `conda install nbconvert pandoc`.

# %% [markdown]
# # Task 1

# %% [markdown]
# ## task 1a)
#
# Fill in image of hand-written notes which are easy to read, or latex equations here

# %% [markdown]
# ![ca0ce3ea-3e2e-49f5-bd3c-c3fe60bcd4fe.jpeg](attachment:ca0ce3ea-3e2e-49f5-bd3c-c3fe60bcd4fe.jpeg)
# ### b) (iii) Max pooling
# ![1e31129c-c990-4cdc-b290-f41968b8e2ff.jpeg](attachment:1e31129c-c990-4cdc-b290-f41968b8e2ff.jpeg)
# ![4c1e45e1-1dc5-4870-9b99-c0f5977ef169.jpeg](attachment:4c1e45e1-1dc5-4870-9b99-c0f5977ef169.jpeg)

# %% [markdown]
# # Task 2
#
# ### Task 2a)
# ![task2a.png](attachment:task2a.png)
# ### Task 2b)
# Dataset: train, Accuracy: 0.828, loss: 0.516\
# Dataset: test, Accuracy: 0.727, loss: 0.791\
# Dataset: val, Accuracy: 0.735, loss: 0.770

# %% [markdown]
# # Task 3

# %% [markdown]
# ### Task 3a)
# ![image-5.png](attachment:image-5.png)\
# batch_size = 64\
# learning_rate = 5e-2\
# early_stop_count = 4\
# for every conv layer kernel=3, stride=1, padding=1
# ### Task 3b)
# Dataset: train, Accuracy: 0.903, loss: 0.302\
# Dataset: test, Accuracy: 0.767, loss: 0.715\
# Dataset: val, Accuracy: 0.766, loss: 0.699\
# ![image-2.png](attachment:image-2.png)
# ### Task 3c)
# We saw most improvement with the batch normalization and makin the kernels smaller.
#
# ### Task 3d)
# Batch normalization:
# ![image-3.png](attachment:image-3.png)
# Batch normalization address issues related to internal covariate shift, which is the change in the distribution of the inputs to a neural network's layers during training\
# .\
# Changing kernel from 5 to 3 and padding from 2 to 1:
# ![image-6.png](attachment:image-6.png)\
# Smaller kernels have fewer parameters than larger kernels. This parameter efficiency can help prevent overfitting
#
# ![image.png](attachment:image.png)
# ### Task 3e)
# with horizontal flipping(p=0.5)
# ![image-4.png](attachment:image-4.png)
# Dataset: train, Accuracy: 0.868, loss: 0.385\
# Dataset: test, Accuracy: 0.805, loss: 0.572\
# Dataset: val, Accuracy: 0.814, loss: 0.564\
#
# horizontal flipping improved our model alot becuase of bigger test data
#
#
# ### Task 3f)
#
# not really any signs of overfitting. the moddel stopped at 10 epochs. and validation loss is quite close to the training loss

# %% [markdown]
# # Task 4

# %% [markdown]
# ## Task 4a)
# ![Figure_1.png](attachment:Figure_1.png)
# Dataset: train, Accuracy: 0.958, loss: 0.133\
# Dataset: test, Accuracy: 0.880, loss: 0.371\
# Dataset: val, Accuracy: 0.893, loss: 0.324
