# %% [markdown]
# # Assignment 240 Report

# %% [markdown]
# This is an outline for your report to ease the amount of work required to create your report. Jupyter notebook supports markdown, and I recommend you to check out this [cheat sheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet). If you are not familiar with markdown.
#
# Before delivery, **remember to convert this file to PDF**. You can do it in two ways:
# 1. Print the webpage (ctrl+P or cmd+P)
# 2. Export with latex. This is somewhat more difficult, but you'll get somehwat of a "prettier" PDF. Go to File -> Download as -> PDF via LaTeX. You might have to install nbconvert and pandoc through conda; `conda install nbconvert pandoc`.

# %% [markdown]
# # Task 1

# %% [markdown]
# ## task 1a)
#
# Fill in task 1a image of hand-written notes which are easy to read, or latex equations here

# %% [markdown]
# ## task 1a)
#
# Fill in task 1a image of hand-written notes which are easy to read, or latex equations here

# %% [markdown]
# # Task 2
# Mean: 33.55, stddev: 78.88

# %% [markdown]
# ## Task 2c)
# ![task2c_train_loss.png](attachment:6317e580-5d88-4e39-999b-df7564c96dfb.png)

# %% [markdown]
# ## Task 2d)
# 785 * 64 + 64 * 10 = 50880 number of parameters

# %% [markdown]
# # Task 3

# %% [markdown]
# ![Figure_2.png](attachment:b25bfefc-2b1b-4775-adac-2420732caf9a.png)
# In your report, please: Shortly comment on the change in performance, which has hopefully improved
# with each addition, at least in terms of learning speed. Note that we expect you to comment on
# convergence speed, generalization/overfitting, and final accuracy/validation loss of the model.

# %% [markdown]
# # Task 4
# In you report, please answer the following:\
# (a) [4pt] (report) Set the number of hidden units to 32. What do you observe if the number of hidden
# units is too small
# ?
# (b) [4pt] (report) Set the number of hidden units to 128. What do you observe if the number is too
# large?

# %% [markdown]
# ## Task 4a)
#
# FILL IN ANSWER.

# %% [markdown]
# ## Task 4b)
# FILL IN ANSWER
# ![Figure_3.png](attachment:750b62e4-0e79-4fc3-af92-4d265a5757c5.png)

# %% [markdown]
# ## Task 4d)
# Create a new model with two hidden layers of equal size. The model should have approximately
# the same number of parameters as the network froracy.
# (report) How does the network with multiple hidden layers compare to the previous
# Task 3) 785 * 64 + 64 * 10 = 50880 number of parameters
# New network with hidden layers: 785 * 59 + 59 * 59 + 59 * 10 = 50386 number of parametersetwork?

# %% [markdown]
# ## Task 4e)
# Train a model with ten hidden layers where each layer has 64 hidden nodes.
# (report) Plot the training loss in the same graph as your baseline from task 3 (you can plot it in
# the same graph as task 4d). What happens with the model? What is the reason for the change in
# model performance?
# ![Figure_4.png](attachment:2770261f-cea7-41f7-bc93-19c333408544.png)
